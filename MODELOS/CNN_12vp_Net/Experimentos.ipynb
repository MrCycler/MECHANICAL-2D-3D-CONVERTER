# %%
# !wget https://people.cs.umass.edu/~zlun/papers/SketchModeling/TestingData.7z
# Out:
# --2020-07-09 20:21:32--  https://people.cs.umass.edu/~zlun/papers/SketchModeling/TestingData.7z
# Resolving people.cs.umass.edu (people.cs.umass.edu)... 128.119.240.99
# Connecting to people.cs.umass.edu (people.cs.umass.edu)|128.119.240.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7247240 (6.9M)
# Saving to: ‘TestingData.7z’
#
# TestingData.7z      100%[===================>]   6.91M  8.57MB/s    in 0.8s
#
# 2020-07-09 20:21:33 (8.57 MB/s) - ‘TestingData.7z’ saved [7247240/7247240]

# %%
# !wget http://neghvar.cs.umass.edu/public_data/zhaoliang_lun_checkpoint.7z
# Out:
# --2020-07-09 20:21:35--  http://neghvar.cs.umass.edu/public_data/zhaoliang_lun_checkpoint.7z
# Resolving neghvar.cs.umass.edu (neghvar.cs.umass.edu)... 128.119.243.3
# Connecting to neghvar.cs.umass.edu (neghvar.cs.umass.edu)|128.119.243.3|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12744082283 (12G) [application/x-7z-compressed]
# Saving to: ‘zhaoliang_lun_checkpoint.7z’
#
# zhaoliang_lun_check 100%[===================>]  11.87G  31.7MB/s    in 6m 26s
#
# 2020-07-09 20:28:01 (31.5 MB/s) - ‘zhaoliang_lun_checkpoint.7z’ saved [12744082283/12744082283]

# %%
# !git clone https://github.com/happylun/SketchModeling
# Out:
# Cloning into 'SketchModeling'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 1911 (delta 5), reused 0 (delta 0), pack-reused 1896
# Receiving objects: 100% (1911/1911), 6.13 MiB | 680.00 KiB/s, done.
# Resolving deltas: 100% (370/370), done.

# %%
!7z x TestingData.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 7247240 bytes (7078 KiB)
#
# Extracting archive: TestingData.7z
# --
# Path = TestingData.7z
# Type = 7z
# Physical Size = 7247240
# Headers Size = 9015
# Method = LZMA:12m
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 270
# Files: 498
# Size:       9348433
# Compressed: 7247240

# %%
!7z x zhaoliang_lun_checkpoint.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 12744082283 bytes (12 GiB)
#
# Extracting archive: zhaoliang_lun_checkpoint.7z
# --
# Path = zhaoliang_lun_checkpoint.7z
# Type = 7z
# Physical Size = 12744082283
# Headers Size = 404
# Method = LZMA:26
# Solid = +
# Blocks = 5
#
# Everything is Ok
#
# Folders: 4
# Files: 9
# Size:       14455280172
# Compressed: 12744082283

# %%
# !python --version
# !apt-get install python3.5
# !python3.5 --version
# Out:
# Python 3.6.9
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3.5 is already the newest version (3.5.9-1+bionic1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 79 not upgraded.
# Python 3.5.9

# %%
# !pip -V
# Out:
# pip 20.1.1 from /usr/local/lib/python3.5/dist-packages/pip (python 3.5)

# %%
# !pip install tensorflow==1.0.1
# !pip install scipy==0.19.0
# !pip install numpy==1.12.1
# Out:
# ...
#      |████████████████████████████████| 16.8 MB 86 kB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
# ...

# %%
# !pip freeze
# Out:
# GDAL==2.2.2
# numpy==1.12.1
# protobuf==3.12.2
# pygobject==3.26.1
# python-apt==1.6.5+ubuntu0.3
# scipy==0.19.0
# screen-resolution-extra==0.0.0
# six==1.15.0
# tensorflow==1.0.1
# xkit==0.0.0

# %%
# !python3.5 SketchModeling/Network/code/MonsterNet/main.py --test --data_dir CharacterDraw/ --train_dir Checkpoint/Character/ --test_dir test_dir
# Out:
# start running...
# Loading testing data...
# Building network...
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE3 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python3.5 SketchModeling/Network/code/MonsterNet/main.py --test --data_dir ChairDraw/ --train_dir Checkpoint/Chair/ --test_dir test_dir2
# Out:
# start running...
# Loading testing data...
# Building network...
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE3 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...
